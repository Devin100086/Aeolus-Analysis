# %%
import pandas as pd

file_path = "data/Aeolus/Flight_Tab/flight_with_weather_2024.csv"
df = pd.read_csv(file_path)

df.head(1)
# Out:
#                FL_DATE OP_CARRIER  OP_CARRIER_FL_NUM ORIGIN DEST  \
# 0  2024-01-01 00:00:00         9E             4814.0    JFK  DTW
#
#           CRS_DEP_TIME             DEP_TIME  DEP_DELAY  TAXI_OUT  \
# 0  2024-01-01 12:52:00  2024-01-01 12:47:00       -5.0      31.0
#
#             WHEELS_OFF  ... O_TEMP  O_PRCP O_WSPD D_TEMP  D_PRCP  D_WSPD  \
# 0  2024-01-01 13:18:00  ...    4.4     0.0   11.2    0.0     0.0    13.0
#
#    O_LATITUDE  O_LONGITUDE  D_LATITUDE  D_LONGITUDE
# 0    40.63975    -73.77893    42.21206    -83.34884
#
# [1 rows x 34 columns]

# %%
df["ARR_DELAY"] > 0
# Out:
# 2275540
